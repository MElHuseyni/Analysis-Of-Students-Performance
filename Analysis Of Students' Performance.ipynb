# %% [markdown]
# # Analysis Of Students' Performance

# %%
import collections
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
stud_df = pd.read_csv('xAPI-Edu-Data.csv')
stud_df.head(5)
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
stud_df['gender'].value_counts()
# Out:
# M    305
# F    175
# Name: gender, dtype: int64

# %%
print('Percentage',stud_df.gender.value_counts(normalize=True))
stud_df.gender.value_counts(normalize=True).plot(kind='bar')
# Out:
# Percentage M    0.635417
# F    0.364583
# Name: gender, dtype: float64

# %%
stud_df['PlaceofBirth'].value_counts()
# Out:
# KuwaIT         180
# Jordan         176
# Iraq            22
# lebanon         19
# USA             16
# SaudiArabia     16
# Palestine       10
# Egypt            9
# Tunis            9
# Syria            6
# Lybia            6
# Iran             6
# Morocco          4
# venzuela         1
# Name: PlaceofBirth, dtype: int64

# %%
fig, (axis1, axis2)  = plt.subplots(2, 1,figsize=(10,10))
sns.countplot(x='Topic', data=stud_df, ax=axis1)
sns.countplot(x='NationalITy', data=stud_df, ax=axis2)

# %%
fig, axarr  = plt.subplots(2,2,figsize=(10,10))
sns.countplot(x='gender', hue='Class', data=stud_df, ax=axarr[0,0], order=['M','F'], hue_order=['L','M','H'])
sns.countplot(x='gender', hue='Relation', data=stud_df, ax=axarr[0,1], order=['M','F'])
sns.countplot(x='gender', hue='StudentAbsenceDays', data=stud_df, ax=axarr[1,0], order=['M','F'])
sns.countplot(x='gender', hue='ParentAnsweringSurvey', data=stud_df, ax=axarr[1,1], order=['M','F'])

# %% [markdown]
#    1. Girls seem to have performed better than boys
#    1. In the case of girls, mothers seem to be more interested in their education than fathers
#    1. Girls had much better attendance than boys

# %%
fig, (axis1, axis2)  = plt.subplots(2, 1,figsize=(10,10))
sns.countplot(x='Topic', hue='gender', data=stud_df, ax=axis1)
sns.countplot(x='NationalITy', hue='gender', data=stud_df, ax=axis2)

# %%
fig, (axis1, axis2)  = plt.subplots(2, 1,figsize=(10,10))
sns.countplot(x='NationalITy', hue='Relation', data=stud_df, ax=axis1)
sns.countplot(x='NationalITy', hue='StudentAbsenceDays', data=stud_df, ax=axis2)

# %%
pd.crosstab(stud_df['Class'],stud_df['Topic'])
# Out:
# Topic  Arabic  Biology  Chemistry  English  French  Geology  History  IT  \
# Class
# H          19       16         10       17      20        6        4  15
# L          17        4          8       10      16        0        3  38
# M          23       10          6       18      29       18       12  42
#
# Topic  Math  Quran  Science  Spanish
# Class
# H         6      8       16        5
# L         7      6       10        8
# M         8      8       25       12

# %%
sns.countplot(x='StudentAbsenceDays',data = stud_df, hue='Class',palette='dark')
plt.show()

# %%
P_Satis = sns.countplot(x="ParentschoolSatisfaction",data=stud_df,linewidth=2,edgecolor=sns.color_palette("dark"))

# %%
fig, axarr  = plt.subplots(2,2,figsize=(10,10))
sns.barplot(x='Class', y='VisITedResources', data=stud_df, order=['L','M','H'], ax=axarr[0,0])
sns.barplot(x='Class', y='AnnouncementsView', data=stud_df, order=['L','M','H'], ax=axarr[0,1])
sns.barplot(x='Class', y='raisedhands', data=stud_df, order=['L','M','H'], ax=axarr[1,0])
sns.barplot(x='Class', y='Discussion', data=stud_df, order=['L','M','H'], ax=axarr[1,1])

# %% [markdown]
# As expected, those that participated more (higher counts in Discussion, raisedhands, AnnouncementViews, RaisedHands), performed better ...that thing about correlation and causation.

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(10,5))
sns.barplot(x='gender', y='raisedhands', data=stud_df, ax=axis1)
sns.barplot(x='gender', y='Discussion', data=stud_df, ax=axis2)

# %%
fig, (axis1, axis2)  = plt.subplots(1, 2,figsize=(10,5))
sns.boxplot(x='Class', y='Discussion', data=stud_df, order=['L','M','H'], ax=axis1)
sns.boxplot(x='Class', y='VisITedResources', data=stud_df, order=['L','M','H'], ax=axis2)

# %%
fig, (axis1, axis2)  = plt.subplots(1, 2,figsize=(10,5))
sns.regplot(x='raisedhands', y='VisITedResources', data=stud_df, ax=axis1)
sns.regplot(x='AnnouncementsView', y='Discussion', data=stud_df, ax=axis2)

# %% [markdown]
# There does not appear to be much of a linear relationship between the numerical features.

# %% [markdown]
# **Gender Comparison With Parents Relationship**

# %%
# gender comparison Relationship with Pare
plot = sns.countplot(x='Class', hue='Relation', data=stud_df, order=['L', 'M', 'H'], palette='Set1')
plot.set(xlabel='Class', ylabel='Count', title='Gender comparison')
plt.show()

# %% [markdown]
# **Pair Plot**

# %%
sns.pairplot(stud_df,hue='Class')

# %%
stud_df.dtypes
# Out:
# gender                      object
# NationalITy                 object
# PlaceofBirth                object
# StageID                     object
# GradeID                     object
# SectionID                   object
# Topic                       object
# Semester                    object
# Relation                    object
# raisedhands                  int64
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentAnsweringSurvey       object
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
stud_df.isnull().values.any()
# Out:
# False

# %%
stud_df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %% [markdown]
# ## Machine Learning

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier, plot_importance

# %%
X = stud_df.drop('Class', axis=1)
y = stud_df['Class']

# Encoding our categorical columns in X
labelEncoder = LabelEncoder()
cat_columns = X.dtypes.pipe(lambda x: x[x == 'object']).index
for col in cat_columns:
    X[col] = labelEncoder.fit_transform(X[col])

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=52)


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (384, 16)
# (384,)
# (96, 16)
# (96,)

# %%
X_imp = stud_df[['VisITedResources','raisedhands','AnnouncementsView',
                'StudentAbsenceDays','Discussion']]

# Encoding our categorical columns in X
labelEncoder = LabelEncoder()
cat_columns = X_imp.dtypes.pipe(lambda x: x[x == 'object']).index
for col in cat_columns:
    X[col] = labelEncoder.fit_transform(X_imp[col])
X_train_imp, X_test_imp, y_train_imp, y_test_imp = train_test_split(X_imp, y, test_size=0.2, random_state=52)

print(X_train_imp.shape)
print(y_train.shape)
print(y_train_imp.shape)
print(y_test_imp.shape)
# Out:
# (384, 5)
# (384,)
# (384,)
# (96,)

# %% [markdown]
# ## Logistic Regression

# %%
Logit_Model = LogisticRegression()
Logit_Model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
Prediction = Logit_Model.predict(X_test)
Score = accuracy_score(y_test,Prediction)
Report = classification_report(y_test,Prediction)

# %%
print(Prediction)
# Out:
# ['L' 'M' 'L' 'L' 'M' 'L' 'M' 'H' 'M' 'M' 'M' 'L' 'M' 'L' 'M' 'L' 'H' 'M'
#  'H' 'M' 'H' 'H' 'L' 'L' 'H' 'L' 'M' 'H' 'H' 'L' 'M' 'H' 'L' 'M' 'M' 'L'
#  'L' 'H' 'H' 'L' 'M' 'M' 'H' 'M' 'H' 'L' 'M' 'L' 'M' 'L' 'H' 'H' 'M' 'M'
#  'H' 'L' 'H' 'L' 'L' 'M' 'L' 'H' 'M' 'M' 'H' 'M' 'L' 'L' 'H' 'M' 'M' 'H'
#  'H' 'H' 'H' 'H' 'M' 'H' 'H' 'H' 'L' 'H' 'M' 'M' 'L' 'M' 'M' 'H' 'M' 'M'
#  'L' 'M' 'M' 'H' 'M' 'H']

# %%
print(Score)
# Out:
# 0.8020833333333334

# %% [markdown]
# ## Decision Tree

# %%
dt_clf = DecisionTreeClassifier()

# %%
dt_clf.fit(X_train,y_train)
dt_prediction = dt_clf.predict(X_test)
dt_Score = accuracy_score(y_test,dt_prediction)
print(dt_Score)
# Out:
# 0.8125

# %%
mlp_clf = MLPClassifier(solver='lbfgs', 
                        alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1)

# %%
mlp_clf.fit(X_train,y_train)
mlp_prediction = mlp_clf.predict(X_test)
mlp_Score = accuracy_score(y_test,mlp_prediction)
print(mlp_Score)
# Out:
# 0.5104166666666666

# %%
from keras.models import Sequential
from keras.layers import Dense
# create model
model = Sequential()
model.add(Dense(12, input_dim=16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='softmax'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train,y_train, epochs=5)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-db34c3beb7b6> in <module>()
# ----> 1 model.fit(X_train,y_train, epochs=5)
#
# ~/.local/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ...

# %% [markdown]
# # **Ensemble Methods (Random Forest and XGBoost)**

# %% [markdown]
# ## Random Forest Classifier

# %%
rnf_clf = RandomForestClassifier(n_estimators=300, random_state=52)

# %%
rnf_clf.fit(X_train,y_train)
rnf_prediction = rnf_clf.predict(X_test)
rnf_Score = accuracy_score(y_test,rnf_prediction)
print(rnf_Score)
# Out:
# 0.8541666666666666

# %%
dn = {'features':X.columns, 'score':rnf_clf.feature_importances_}
df = pd.DataFrame.from_dict(data=dn).sort_values(by='score', ascending=False)
plot = sns.barplot(x='score', y='features', data=df, orient='h')
plot.set(xlabel='Score', ylabel='Features', 
         title='Feature Importance of Random Forest Classifier')
plt.setp(plot.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# ##  Graident Boosting Tree

# %%
xgb = XGBClassifier(max_depth=10, learning_rate=0.1, n_estimators=100,seed=10)
xgb_pred = xgb.fit(X_train, y_train).predict(X_test)
# Out:
# /home/mahmoud/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
print(xgb_pred)
# Out:
# ['L' 'H' 'L' 'L' 'M' 'L' 'M' 'H' 'M' 'M' 'M' 'L' 'M' 'L' 'M' 'L' 'M' 'M'
#  'H' 'M' 'H' 'H' 'L' 'L' 'H' 'L' 'H' 'H' 'M' 'L' 'M' 'M' 'L' 'H' 'M' 'M'
#  'L' 'M' 'H' 'L' 'H' 'M' 'M' 'H' 'M' 'L' 'L' 'L' 'M' 'L' 'H' 'H' 'M' 'M'
#  'H' 'L' 'M' 'L' 'L' 'M' 'L' 'H' 'M' 'H' 'H' 'M' 'L' 'M' 'H' 'H' 'M' 'H'
#  'H' 'H' 'H' 'H' 'M' 'H' 'H' 'M' 'L' 'H' 'M' 'M' 'L' 'M' 'M' 'H' 'M' 'H'
#  'L' 'M' 'M' 'H' 'M' 'H']

# %%
print(accuracy_score(y_test,xgb_pred))
# Out:
# 0.84375

# %%
plot_importance(xgb)
